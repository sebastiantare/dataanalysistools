# %% [markdown]
# # How to work with distributions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Color Palette
sns.set_palette("Paired")
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
from sklearn.datasets import load_iris

data = load_iris()

df = pd.DataFrame(data['data'], columns=data['feature_names'])
X = df.copy()

features = df.columns.to_list()

df['target'] = data['target']
y = df['target'].copy()

df.describe().T.style.bar()
# Out:
# <style type="text/css">
# #T_f4b6b_row0_col0, #T_f4b6b_row0_col1, #T_f4b6b_row0_col3, #T_f4b6b_row0_col4, #T_f4b6b_row0_col5, #T_f4b6b_row0_col6, #T_f4b6b_row0_col7, #T_f4b6b_row1_col0, #T_f4b6b_row2_col0, #T_f4b6b_row2_col2, #T_f4b6b_row3_col0, #T_f4b6b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f4b6b_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.9%, transparent 46.9%);
# }
# #T_f4b6b_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 52.3%, transparent 52.3%);
# }
# #T_f4b6b_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.7%, transparent 24.7%);
# }
# #T_f4b6b_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.5%, transparent 46.5%);
# }
# #T_f4b6b_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.9%, transparent 54.9%);
# }
# #T_f4b6b_row1_col5 {
#   width: 10em;
# ...

# %% [markdown]
# ## 1) Visualization

# %% [markdown]
# ### Simple

# %%
X[features[0]].plot.kde();

# %%
# Line
for feature in features:
    X[feature].plot.kde(label=feature)
plt.legend()
plt.show()

# %%
# Kde distplot
sns.displot(X, x=features[0], kde=True);

# %%
# Bins
sns.displot(X, x=features[0], bins=20, kde=True);

# %%
# Smoothing bandwidth
sns.displot(X, x=features[0], kind='kde', bw_adjust=1.6);

# %%
# For small data, like classes
sns.displot(df, x="target");

# %%
# separate multiclass distribution
sns.displot(X, x=features[0], col=y, kde=True);

# %%
# Multiclass color for target
sns.displot(df, x=features[0], hue="target", kind="kde");

# %% [markdown]
# ### Complex

# %%
# For visualizing class separability
sns.displot(df, x=features[0], y=features[1], hue="target");

# %% [markdown]
# ## 2) Transformation
